# %%
import pyspark.sql.functions as f

# %%
df = spark.read.table('workspace.nyc_cleansed.yellow_taxi')

# %% [markdown]
# Columns Renaming

# %%
rename_cols = {
    "tpep_pickup_datetime":"pickup_datetime",
    "tpep_dropoff_datetime":"dropoff_datetime",
    "pulocationid":"pickup_location_id",
    "dolocationid":"dropoff_location_id",
    "payment_type":"payment_type_id"
}

for key,val in rename_cols.items():
    df = df.withColumnRenamed(key,val)

select_cols = [
    'pickup_datetime',
    'dropoff_datetime',
    'passenger_count',
    'trip_distance',
    'pickup_location_id',
    'dropoff_location_id',
    'payment_type_id',
    'fare_amount',
    'extra',
    'mta_tax',
    'tip_amount',
    'tolls_amount',
    'improvement_surcharge',
    'total_amount',
    'congestion_surcharge',
    'airport_fee'
]

df = df.select(*select_cols)

# %% [markdown]
# Filtering Out Bad Records

# %%
df = df.filter( (f.col('fare_amount') > 0.0 ) | ( f.col('total_amount') > 0.0) )\
       .filter(f.col('pickup_datetime') < f.col('dropoff_datetime'))\
       .filter(f.col('passenger_count') > 0)\
       .filter(f.col('trip_distance') > 0)

# %% [markdown]
# Adding Primary Key

# %%
df = df.withColumn('trip_id',f.md5(f.concat_ws( f.col('pickup_datetime'),f.col('dropoff_datetime'),f.col('pickup_location_id'),f.col('dropoff_location_id'),f.col("trip_distance"))))

df = df.withColumn('trip_id',f.regexp_replace(
                                            f.col('trip_id'),
                                            "(.{8})(.{4})(.{4})(.{4})(.{12})",
                                            "$1-$2-$3-$4-$5"
                                            )
                )

# %% [markdown]
# Adding Calculated Columns

# %%
df = df\
    .withColumn('trip_duration',f.round( (f.unix_timestamp('dropoff_datetime') - f.unix_timestamp('pickup_datetime'))/3600 , 2)) \
    .withColumn('avg_speed',f.round( f.try_divide(f.col("trip_distance"),f.col('trip_duration')) , 2)) \
    .withColumn('fare_amount_per_mile',f.round( f.try_divide(f.col('fare_amount'),f.col('trip_distance')) , 2))\
    .withColumn('cost_per_mile',f.round( f.try_divide(f.col('total_amount'),f.col('trip_distance')) , 2))\
    .withColumn('tip_percentage',f.round( (f.try_divide(f.col('tip_amount'),f.col('total_amount') - f.col('tip_amount')))*100 , 2))\
    .withColumn('is_rush_hour',f.when(f.hour('pickup_datetime').between(7,10) | f.hour('pickup_datetime').between(17,21) ,f.lit(True))
                                .otherwise(f.lit(False))
                )\
    .withColumn('is_cashless',f.when(f.col('payment_type_id') == 1 , f.lit(True)).otherwise(f.lit(False)))

# %% [markdown]
# Adding Columns from other tables

# %%
df_taxi_zone_lookup = spark.read.table('nyc_enterprise.taxi_zone_lookup')

pickup_taxi_zone = df_taxi_zone_lookup.select(f.col('location_id').alias('pickup_location_id'),f.col('borough').alias('pickup_borough'),f.col('zone').alias('pickup_zone'),f.col('service_zone').alias('pickup_service_zone'))

dropoff_taxi_zone = df_taxi_zone_lookup.select(f.col('location_id').alias('dropoff_location_id'),f.col('borough').alias('dropoff_borough'),f.col('zone').alias('dropoff_zone'),f.col('service_zone').alias('dropoff_service_zone'))

df = df.alias('yellow_taxi').join(
              pickup_taxi_zone.alias('pickup_taxi_zone'),
              df.pickup_location_id == pickup_taxi_zone.pickup_location_id,
              how='left'
            )\
       .join(
              dropoff_taxi_zone.alias('dropoff_taxi_zone'),
              df.dropoff_location_id == dropoff_taxi_zone.dropoff_location_id,
              how='left'
       )

df = df.drop(f.col('pickup_taxi_zone.pickup_location_id'),f.col('dropoff_taxi_zone.dropoff_location_id'))

# %%
# Derviving some location based columns
df = df.withColumn('is_same_location_trip_flag',f.when(f.col('pickup_location_id') == f.col('dropoff_location_id'),f.lit(True)).otherwise(False))\
       .withColumn('is_same_borough_trip_flag',f.when(f.col('pickup_borough') == f.col('dropoff_borough'),f.lit(True)).otherwise(False))\
       .withColumn('is_same_zone_trip_flag',f.when(f.col('pickup_zone') == f.col('dropoff_zone'),f.lit(True)).otherwise(False))\
       .withColumn('is_same_service_zone_trip_flag',f.when(f.col('pickup_service_zone') == f.col('dropoff_service_zone'),f.lit(True)).otherwise(False))\
       .withColumn('is_airport_pickup',f.when(f.col('pickup_service_zone') == 'Airports',f.lit(True)).otherwise(f.lit(False)))\
       .withColumn('is_airport_dropoff',f.when(f.col('dropoff_service_zone') == 'Airports',f.lit(True)).otherwise(f.lit(False)))

# %%
select_cols = ["trip_id"] + select_cols + ["trip_duration","avg_speed","fare_amount_per_mile","cost_per_mile","tip_percentage","is_rush_hour","is_cashless","is_same_location_trip_flag","is_same_borough_trip_flag","is_same_zone_trip_flag","is_same_service_zone_trip_flag","is_airport_pickup","is_airport_dropoff"]

df = df.select(*select_cols)

# %%
display(df)

# %%
from pyspark.sql.window import Window

# %%
df_window = Window.partitionBy('trip_id').orderBy(f.desc('total_amount'))

df = df.withColumn('rnk',f.row_number().over(df_window))\
       .filter(f.col('rnk') == 1 )

# %%
# checking for duplicates
display(df.groupBy('trip_id').agg(f.count('*').alias('cnt')).filter(f.col('cnt') > 1))

# %%
source_df = df

# %% [markdown]
# Implement SCD-2

# %%
from delta.tables import *

try:

    if not spark.catalog.tableExists("nyc_enterprise.yellow_taxi"):
        raise ValueError(f"Error: The Delta table nyc_enterprise.yellow_taxi was not found.")
    
    target_df = DeltaTable.forName(spark, "nyc_enterprise.yellow_taxi")
    print("Loaded existing Delta table")

except Exception as e:
    print(e)
    print('Error While Reading , Creating New Table ')
    target_df = spark.createDataFrame([],schema=source_df.schema)
    target_df = target_df.withColumn('created_by',f.lit('manual'))\
                         .withColumn('modified_by',f.lit(''))\
                         .withColumn('effective_start_date',f.current_date())\
                         .withColumn('effective_end_date',f.lit('9999-12-31').cast('date'))\
                         .withColumn('is_active',f.lit(True))
            
    target_df = target_df.drop('rnk')
    
    spark.sql('CREATE SCHEMA IF NOT EXISTS workspace.nyc_enterprise')
    target_df.write.mode('overwrite').saveAsTable('workspace.nyc_enterprise.yellow_taxi')
    target_df = DeltaTable.forName(spark,"nyc_enterprise.yellow_taxi")
    print('Table Created')

source_df = source_df.withColumn('created_by',f.lit('data-pipeline'))\
                        .withColumn('modified_by',f.lit(''))\
                        .withColumn('effective_start_date',f.current_date())\
                        .withColumn('effective_end_date',f.lit('9999-12-31').cast('date'))\
                        .withColumn('is_active',f.lit(True))

source_df = source_df.drop('rnk')

print('Performing SCD - 2')
# Expiring Exisiting Records
target_df.alias('target').merge(
    source_df.alias('source'),
    """
    source.trip_id = target.trip_id 
    AND target.is_active = true
    """
).whenMatchedUpdate(
    condition = """
        source.passenger_count <> target.passenger_count
        OR source.payment_type_id <> target.payment_type_id
        OR source.fare_amount <> target.fare_amount
        OR source.extra <> target.extra
        OR source.mta_tax <> target.mta_tax
        OR source.tip_amount <> target.tip_amount
        OR source.tolls_amount <> target.tolls_amount
        OR source.improvement_surcharge <> target.improvement_surcharge
        OR source.total_amount <> target.total_amount
        OR source.congestion_surcharge <> target.congestion_surcharge
        OR source.airport_fee <> target.airport_fee
        OR source.trip_duration <> target.trip_duration
        OR source.avg_speed <> target.avg_speed
        OR source.fare_amount_per_mile <> target.fare_amount_per_mile
        OR source.cost_per_mile <> target.cost_per_mile
        OR source.tip_percentage <> target.tip_percentage
        OR source.is_rush_hour <> target.is_rush_hour
        OR source.is_cashless <> target.is_cashless
        OR source.is_same_location_trip_flag <> target.is_same_location_trip_flag
        OR source.is_same_borough_trip_flag <> target.is_same_borough_trip_flag
        OR source.is_same_zone_trip_flag <> target.is_same_zone_trip_flag
        OR source.is_same_service_zone_trip_flag <> target.is_same_service_zone_trip_flag
        OR source.is_airport_pickup <> target.is_airport_pickup
        OR source.is_airport_dropoff <> target.is_airport_dropoff
    """,
    set = {
        "effective_end_date": "current_date()",
        "modified_by": "'data-pipeline'",
        "is_active": "false"
    }
).execute()

# Inserting New & Updated Records
target_df.alias('target').merge(
    source_df.alias('source'),
    """
    source.trip_id = target.trip_id
    AND target.is_active = true
    """
).whenNotMatchedInsert(
    values = {  
        "pickup_datetime": "source.pickup_datetime",
        "dropoff_datetime": "source.dropoff_datetime",
        "passenger_count": "source.passenger_count",
        "trip_distance": "source.trip_distance",
        "pickup_location_id": "source.pickup_location_id",
        "dropoff_location_id": "source.dropoff_location_id",
        "payment_type_id": "source.payment_type_id",
        "fare_amount": "source.fare_amount",
        "extra": "source.extra",
        "mta_tax": "source.mta_tax",
        "tip_amount": "source.tip_amount",
        "tolls_amount": "source.tolls_amount",
        "improvement_surcharge": "source.improvement_surcharge",
        "total_amount": "source.total_amount",
        "congestion_surcharge": "source.congestion_surcharge",
        "airport_fee": "source.airport_fee",
        "trip_id": "source.trip_id",
        "trip_duration": "source.trip_duration",
        "avg_speed": "source.avg_speed",
        "fare_amount_per_mile": "source.fare_amount_per_mile",
        "cost_per_mile": "source.cost_per_mile",
        "tip_percentage": "source.tip_percentage",
        "is_rush_hour": "source.is_rush_hour",
        "is_cashless": "source.is_cashless",
        "is_same_location_trip_flag": "source.is_same_location_trip_flag",
        "is_same_borough_trip_flag": "source.is_same_borough_trip_flag",
        "is_same_zone_trip_flag": "source.is_same_zone_trip_flag",
        "is_same_service_zone_trip_flag": "source.is_same_service_zone_trip_flag",
        "is_airport_pickup": "source.is_airport_pickup",
        "is_airport_dropoff": "source.is_airport_dropoff",
        "created_by": "'data-pipeline'",
        "modified_by": "NULL",
        "effective_start_date": "current_date()",
        "effective_end_date": "CAST('9999-12-31' AS DATE)",
        "is_active": "true"
    }
).execute()

print('SCD - 2 Completed')

# %%
# %sql
# update nyc_cleansed.yellow_taxi set airport_fee = 1.85 where airport_fee = 1.75

# %%
# %sql
select effective_end_date,airport_fee,count(1) from nyc_enterprise.yellow_taxi
group by 1,2
