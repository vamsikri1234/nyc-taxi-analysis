# %%
# %sql
CREATE SCHEMA IF NOT EXISTS nyc_cleaned

# %%
# %run ../utility/read_write_util

# %%
import requests
from datetime import datetime

dataset_path = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"
dbfs_path = "/Volumes/workspace/nyc_cleansed/dataset/NYC/taxi-zone-data/zone-lookup/"

file_copy(dataset_path , dbfs_path + dataset_path.split('/')[-1])

# %%
# Reading Data into DataFrames

read_options = {
    "header": "true",
    "inferSchema": "true"
}

taxi_zone_lookup_df = read_data(source_file_path = dbfs_path + '/taxi_zone_lookup.csv',
                            source_file_format='csv',                  
                            read_options=read_options)

# %%
display(taxi_zone_lookup_df)

# %%
# writing dataframe to table

write_data(
    df = taxi_zone_lookup_df,
    target_file_path = f"nyc_cleansed.taxi_zone_lookup",
    target_file_format='delta',
    mode_type='overwrite'

)

# %%
# %sql
select * from nyc_cleansed.taxi_zone_lookup
