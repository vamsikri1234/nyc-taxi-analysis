# %%
# %sql
CREATE SCHEMA IF NOT EXISTS nyc_cleansed

# %%
# %run ../utility/read_write_util

# %%
# Reading Data into DataFrames

read_options = {
    "header": "true",
    "inferSchema": "true"
}

weather_df = read_data(source_file_path = '/Volumes/workspace/nyc_cleansed/dataset/NYC/weather-data/weather_data.csv',
                            source_file_format='csv',                  
                            read_options=read_options)

# %%
display(weather_df)

# %%
# writing dataframe to table

write_data(
    df = weather_df,
    target_file_path = f"nyc_cleansed.weather_data",
    target_file_format='delta',
    mode_type='overwrite'

)

# %%
# %sql
select * from nyc_cleansed.weather_data
