# %%
# %sql 
select * from workspace.default.weather_data_temp where location = 'New York'

# %%
# %sql

select date(Date_Time),count(1) from workspace.default.weather_data_temp where location = 'New York' group by 1 order by 1

# %%
# %sql

select date(tpep_pickup_datetime),count(1) from workspace.nyc_cleansed.yellow_taxi
group by 1 order by 1
